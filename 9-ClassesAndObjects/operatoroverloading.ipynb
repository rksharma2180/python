# %%
# Operator overloading
# Operator overloading allows us to define the behavior of operators (+,-,*,etc.)
# for custom objects. operator overloading can be acheived by overriding specific
# megic method in class. 

# __add__(self, other): Adds two objects using the + operator
# __sub__(self, other): Subtract two objects using the - operator
# __mul__(self, other): Multiplies two objects using the * operator
# __truediv__(self, other): Divides two objects using / operator
# __eq__(self, other): checks if two objects are equal using == operator
# __lt__(self, other): checks if one object is less than another using < operator
# __gt__

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)
    
    def __mul__(self, other):
        return Vector(self.x * other.x, self.y * other.y)

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
    def __lt__(self, other):
        return self.x < other.x and self.y < other.y

    def __gt__(self, other):
        return self.x > other.x and self.y > other.y
    
    def __repr__(self):
        return f'Vector({self.x}, {self.y})'

vector1 = Vector(2,3)
vector2 = Vector(4,5)

print(f'+ {vector1 + vector2}')
print(f'- {vector1 - vector2}')
print(f'* {vector1 * vector2}')
print(f'== {vector1 == vector2}')
print(f'< {vector1 < vector2}')
print(f'> {vector2 > vector1}')
# Out:
# + Vector(6, 8)
# - Vector(-2, -2)
# * Vector(8, 15)
# == False
# < True
# > True
