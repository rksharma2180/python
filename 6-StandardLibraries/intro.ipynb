# %% [markdown]
# Python's standard library is vast collection of module and packages that come bundled with python, providing a wide range of functionalities out of the box

# %%
import array

arr = array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(12))
print(math.pi)
# Out:
# 3.4641016151377544
# 3.141592653589793

# %%
import random

print(random.randint(1,10))
print(random.choice(['Apple', 'Banana', 'Cherry']))
# Out:
# 10
# Banana

# %%
import os ## Used for file and directory access

print(os.getcwd())
print(os.makedirs('test'))
# Out:
# d:\development\AI\Udemy\KrishNaik\python\6-StandardLibraries
# None

# %%
## High level operation on file or collection of files

import shutil
shutil.copyfile("./test/source.txt", "./test/destination.txt")
# Out:
# './test/destination.txt'

# %%
## Data Serialization

import json

data = {
    "name":"Ravi",
    "age":"35"
}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Ravi", "age": "35"}
# <class 'str'>
# {'name': 'Ravi', 'age': '35'}
# <class 'dict'>

# %%
import xml

print(xml)
# Out:
# <module 'xml' from 'd:\\development\\AI\\Udemy\\KrishNaik\\python\\venv\\Lib\\xml\\__init__.py'>

# %%
## CSV

import csv

with open('example.csv', mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['ravi', '35'])

with open('example.csv',mode='r') as file:
    reader  = csv.reader(file)
    for text in reader:
        print(text)
# Out:
# ['name', 'age']
# ['ravi', '35']

# %%
## Date time

from datetime import datetime, timedelta

current_time = datetime.now()
print(current_time)

print(current_time - timedelta(days=1)) ## Yesterday's time
# Out:
# 2026-02-06 05:09:33.075355
# 2026-02-05 05:09:33.075355

# %%
import time ## for program

print(time.time())

time.sleep(2) ## make current progam sleep for 2 seconds 

print(time.time())
# Out:
# 1770335649.3503559
# 1770335651.3513186

# %%
## Regular Expression
import re

pattern = r'\d+' ## r to preserve raw string
text = "This is my 5th commented on this program whichhas only 3 lines"
match = re.search(pattern,text)

print(match.group())
# Out:
# 5
