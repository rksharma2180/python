# %%
## if statement example
num = 20
if num > 18:
    print("Adult")
# Out:
# Adult

# %%
## Else
number = 15
if number > 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
## Elif allows multiple conditions. It stands for "else if".
age = 25
if age < 13:
    print("Child")
elif age < 20:
    print("Teenager")
else: 
    print("Adult")
# Out:
# Adult

# %%
## Nested if statements
num = 45
if num > 10:
    if num < 50:
        print("Number is between 10 and 50")
    else:
        print("Number is greater than or equal to 50")
# Out:
# Number is between 10 and 50

# %%
## Practical Example 
## Determine if a year is a leap year
year = int(input("Enter a year: ") )
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2012 is a leap year.
