# %% [markdown]
# Decorators are powerful and flaxible feature in python that allows us
# to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code.

# %%
# function copy 
# closures
# decorators

# %%
# function copy
def welcome():
    print('Welcome to the AI world')

welcome()
# Out:
# Welcome to the AI world

# %%
wel = welcome # Copying the function to another variable
type(wel)
wel()
# Out:
# Welcome to the AI world

# %%
del welcome
wel()
# Out:
# Welcome to the AI world

# %%
## Closures - are function inside a function

def main_welcome():
    msg = 'Welcome to programming world'
    def sub_welcome():
        print(msg)

        print('This is the second message')
    return sub_welcome()

main_welcome() # sub_welcome is automatically getting called
# Out:
# Welcome to programming world
# This is the second message

# %%
## Closures - are function inside a function

def main_welcome(func):
    msg = 'Welcome to programming world'
    def sub_welcome():
        func(msg)
        print('This is the second message')
    return sub_welcome()

main_welcome(print) # sub_welcome is automatically getting called
# Out:
# Welcome to programming world
# This is the second message

# %%
# Problem
def main_welcome(func):
    msg = 'Welcome to programming world'
    def sub_welcome():
        print(func())
        print('This is the second message')
    return sub_welcome()

main_welcome(len([1,2,4,5])) #Here len is getting called first and value 4 is being passed to main_welcome()
# and 4 is nothing but int object and object cannot be called thus we get TypeError: 'int' object is not callable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       5         print('This is the second message')
#       6     return sub_welcome()
# ----> 8 main_welcome(len([1,2,4,5])) #Here len is getting called first and value 4 is being passed to main_welcome()
#       9 # and 4 is nothing but int object and object cannot be called thus we get TypeError: 'int' object is not callable
#
# Cell In[11], line 6, in main_welcome(func)
#       4     print(func())
#       5     print('This is the second message')
# ----> 6 return sub_welcome()
#
# Cell In[11], line 4, in main_welcome.<locals>.sub_welcome()
#       3 def sub_welcome():
# ----> 4     print(func())
#       5     print('This is the second message')
#
# TypeError: 'int' object is not callable

# %%
# Solution
def main_welcome(func, list):
    msg = 'Welcome to programming world'
    def sub_welcome():
        print(func(list))
        print('This is the second message')
    return sub_welcome()

main_welcome(len, [1,2,4,5])
# Out:
# 4
# This is the second message

# %%
#Decorators
def main_welcome(func):
    msg = 'Welcome to programming world'
    def sub_welcome():
        print(msg)
        func()
        print('This is the second message')
    return sub_welcome()

main_welcome(print)
# Out:
# Welcome to programming world
#
# This is the second message

# %%
def course_intro():
    print('This is an Advance concept')

course_intro()
# Out:
# This is an Advance concept

# %%
main_welcome(course_intro)
# Out:
# Welcome to programming world
# This is an Advance concept
# This is the second message

# %%
@main_welcome
def course_intro(): # this function is being passed as parameter to main_welcome function
    print('This is an Advance concept')
# Out:
# Welcome to programming world
# This is an Advance concept
# This is the second message

# %%
# Decorator with arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print('Hello')

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello
