# %%
print("Hi There")
# Out:
# Hi There

# %%
### IGNORE BELOW THIS LINE ###

# %%
## THis is the single line comment - multi line comment does not work in ipynb files
'''
    this is multi line comment
'''
# Out:
# '\n    this is multi line comment\n'

# %%
name="Ravi"
Name = "Sharma";
print(name)
print(Name)
# Out:
# Ravi
# Sharma

# %%
## Indentation
if(5>2):
    print("Five is greater than two")
# Out:
# Five is greater than two

# %%
## Line Continuation
total = 1 + 2+ 3 + 5 \
    +     7 + 11 +13
print(total)
# Out:
# 42

# %%
## Multiple Statements in a Single Line
a = 5; b = 10; c = a + b; print(c)
# Out:
# 15

# %%
## Semantics 
## Variable assignment
age = 32
name = "Krish"

print("My name is", name, "and my age is", age)
# Out:
# My name is Krish and my age is 32

# %%
## Type Inference
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
variable = 10
print(type(variable))
variable = "Ten"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=25 
if age >= 18:
print(age)
# Out:
#   Cell In[16], line 3
#     print(age)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
## name 'abc' is not defined
a =abc
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a =abc
#       2 print(a)
#
# NameError: name 'abc' is not defined

# %%
if True:
    print("Hello World")
    if False:
        print("Hello India")
    print("Part of 1st if block")
print("Outside if block")
# Out:
# Hello World
# Part of 1st if block
# Outside if block
