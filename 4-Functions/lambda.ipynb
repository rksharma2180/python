# %%
## Lambda functions are small anonymous function defined using lambda keyword.
## They can have any number of arguments but only 1 expression.
## They are commonly used for short operations or as arguments to higher-order function

# Syntax
lambda arguments: expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def addition(a,b):
    return a+b
print(addition(2,3))
# Out:
# 5

# %%
addition = lambda a,b:a+b
print(type(addition))
print(addition(9,9))
# Out:
# <class 'function'>
# 18

# %%
def even(num):
    if num%2==0:
        return "even"
    else:
        return "odd"
    
even(24)
# Out:
# 'even'

# %%
even_odd = lambda n: n%2 == 0
print(even_odd(12))
print(even_odd(11))
# Out:
# True
# False

# %%
addition = lambda a,b,c: a+b+c
print(f"Sum of 4,6,7 {addition(4,5,7)}")
# Out:
# Sum of 4,6,7 16

# %%
## map() -- Applies a function to all items in  a list
numbers = [1,2,3,4,5,6]
def square(num):
    return num**2

print(square(5))
# Out:
# 25
