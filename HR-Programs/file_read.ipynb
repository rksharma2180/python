# %%
## File Reading operation
def read_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    return content

print(read_file("D:/development/AI/Udemy/KrishNaik/python/sample_file.txt"))
